# %% [markdown]
# ![](pontificia_universidad_javeriana_logo.jpg)

# %% [markdown]
# <h1>Procesamiento de Datos a Gran Escala</h1>

# %% [markdown]
# <h2>Cuaderno 08 - Funciones en Python</h2>

# %% [markdown]
# ---
# **Pontificia Universidad Javeriana**
#
# **Facultad de Ingeniería**
#
# **Materia:** Procesamiento de Datos a Gran Escala
#
# **Número de Clase:** 1055
#
# **Profesor**: John Jairo Corredor Franco
#
# **Autora:** Monica Maria Castro Benitez
#
# **Código:** 00020574755
#
# **Fecha:** 14-08-2026
#
# ---

# %% [markdown]
# ## **Introducción**
#
# <p><strong>¡Bienvenido!</strong> Este cuaderno te va a mostrar acerca del uso de funciones en el lenguaje de programación Python. Al finalizar este laboratorio, sabrás los conceptos básicos acerca de funciones, variables y cómo usar funciones</p>
#
# En este cuaderno se abordan qué es una función, cómo se definen y se llaman, el uso de variables dentro y fuera de una función (alcance o scope), y cómo las funciones facilitan la reutilización de código.

# %% [markdown]
# ## Objetivo General
#
# Comprender y aplicar la creación y uso de funciones en Python para organizar y reutilizar bloques de código.
#
# ## Objetivos Específicos
#
# - Definir funciones propias utilizando la palabra clave `def`, incluyendo el uso de parámetros y valores de retorno.
# - Diferenciar entre variables locales y globales según el alcance (scope) en que son definidas.
# - Aplicar funciones predefinidas de Python para simplificar tareas comunes dentro de un programa.

# %% [markdown]
# ## Resumen de Conceptos Clave
#
# **Función:** Bloque de código reutilizable que realiza una tarea específica. Se define con la palabra clave `def`, seguida del nombre de la función y sus parámetros entre paréntesis.
#
# **Parámetros y argumentos:** Los parámetros son las variables que recibe la función al definirse; los argumentos son los valores reales que se le pasan al llamarla.
#
# **`return`:** Permite que una función devuelva un resultado para ser usado fuera de ella.
#
# **Variables locales y globales:** Una variable definida dentro de una función solo existe dentro de ella (local), mientras que una variable definida fuera puede ser accedida desde cualquier parte del programa (global).

# %% [markdown]
# <h2>Tabla de contenidos</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#func">Funciones</a>
#             <ul>
#                 <li><a href="content">¿Qué es una función?</a></li>
#                 <li><a href="var">Variables</a></li>
#                 <li><a href="simple">Las funciones hacen las cosas más fáciles</a></li>
#             </ul>
#         </li>
#         <li><a href="pre">Funciones predefinidas</a></li>
#         <li><a href="if">Utilizando <code>if</code>/<code>else</code> y ciclos en Funciones</a></li>
#         <li><a href="default">Establecer valores de argumento predeterminados en sus funciones personalizadas</a></li>
#         <li><a href="global">Variables globales</a></li>
#         <li><a href="scope">Ámbito de una variable</a></li>
#         <li>
#             <a href="#quiz">Cuestionario sobre funciones</a>
#         </li>
#     </ul>
#     <p>
#         Tiempo estimado: <strong>40 min</strong>
#     </p>
# </div>
#
# <hr>

# %% [markdown]
# <h2 id="func">Funciones</h2>

# %% [markdown]
# Una función es un bloque de código reutilizable que realiza las operaciones especificadas en la función. Le permiten dividir las tareas y reutilizar su código en diferentes programas.
#
# Hay dos tipos de funciones:
#
# - <b>Funciones predefinidas</b>
# - <b>Funciones definidas por el usuario</b>

# %% [markdown]
# <h3 id="content">¿Qué es una función?</h3>

# %% [markdown]
# Puede definir funciones para proporcionar la funcionalidad requerida. Aquí hay reglas simples para definir una función en Python:
# - Los bloques de funciones comienzan <code> def </code> seguidos por la función <code> name </code> y entre paréntesis <code> () </code>.
# - Hay parámetros de entrada o argumentos que deben colocarse entre estos paréntesis.
# - También puede definir parámetros dentro de estos paréntesis.
# - Hay un cuerpo dentro de cada función que comienza con dos puntos (<code>: </code>) y tiene sangría.
# - También puede colocar la documentación antes del cuerpo.
# - La instrucción <code> return </code> sale de una función y, opcionalmente, devuelve un valor.
#
# Un ejemplo de una función que se agrega al parámetro <code> a </code> imprime y devuelve la salida como <code> b </code>:

# %%
# Primer ejemplo de funcion:  Suma 1 en a y almacena en b

def sum(a):
    b = a + 1
    print(a, "si sumas 1", b)
    return(b)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define la función <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">sum(a)</code> con la palabra clave <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">def</code>. Dentro de ella, <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a</code> es el parámetro de entrada, <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">b = a + 1</code> es una variable local, y <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">return(b)</code> devuelve el resultado al lugar donde se llame la función.</p><p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Nótese que este ejemplo usa <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">sum</code> como nombre de la función (sobrescribiendo la función incorporada del mismo nombre), lo cual se debe tener en cuenta al usarla más adelante.</p>
# </div>

# %% [markdown]
# La siguiente figura ilustra la terminología:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%203/Images/FuncsDefinition.png" width="500" />

# %% [markdown]
# Podemos obtener ayuda sobre una función:

# %%
# Get a help on add function

help(add)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Get a help on add function
#       2
# ----> 3 help(add)
#
# NameError: name 'add' is not defined

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">help(add)</code> intenta mostrar la documentación de una función llamada <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">add</code>. Sin embargo, en la celda anterior se definió la función con el nombre <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">sum</code>, no <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">add</code>; por eso esta celda genera un <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">NameError</code>, ya que Python no reconoce ningún objeto llamado <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">add</code>.</p>
# </div>

# %% [markdown]
# Podemos llamar a la función:

# %%
# Call the function add()

add(1)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">add(1)</code> intenta llamar a la función usando el nombre <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">add</code>. Como solo existe la función <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">sum</code> definida antes, esta llamada también produciría un <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">NameError</code>; para que funcione debería escribirse <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">sum(1)</code>.</p>
# </div>

# %% [markdown]
# Si llamamos a la función con una nueva entrada obtenemos un nuevo resultado:

# %%
# Call the function add()

add(2)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">De la misma forma, <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">add(2)</code> fallaría por el mismo motivo que la celda anterior: el nombre correcto de la función definida es <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">sum</code>, no <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">add</code>.</p>
# </div>

# %% [markdown]
# Podemos crear diferentes funciones. Por ejemplo, podemos crear una función que multiplique dos números. Los números estarán representados por las variables <code> a </code> y <code> b </code>:

# %%
# Define a function for multiple two numbers

def Mult(a, b):
    c = a * b
    return(c)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define la función <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">Mult(a, b)</code>, que recibe dos parámetros, calcula su producto en la variable local <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">c</code>, y lo devuelve con <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">return(c)</code>.</p>
# </div>

# %% [markdown]
# La misma función se puede utilizar para diferentes tipos de datos. Por ejemplo, podemos multiplicar dos números enteros:

# %%
# Use mult() multiply two integers

Mult(2, 3)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">Mult(2, 3)</code> llama a la función con dos números enteros, devolviendo su producto: 6.</p>
# </div>

# %% [markdown]
# Dos Floats:

# %%
# Use mult() multiply two floats

Mult(10.0, 3.14)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">Mult(10.0, 3.14)</code> muestra que la misma función también funciona con números decimales (float), devolviendo 31.4.</p>
# </div>

# %% [markdown]
# Incluso podemos replicar una cadena multiplicándola por un número entero:

# %%
# Use mult() multiply two different type values together

Mult(2, "Michael Jackson ")

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">Mult(2, &quot;Michael Jackson &quot;)</code> muestra que el operador <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">*</code> dentro de la función también funciona entre un entero y una cadena: en vez de una multiplicación numérica, repite el texto dos veces.</p>
# </div>

# %% [markdown]
# <h3 id="var">Variables</h3>

# %% [markdown]
# La entrada a una función se llama parámetro formal.
#
# Una variable que se declara dentro de una función se llama variable local. El parámetro solo existe dentro de la función (es decir, el punto donde la función comienza y se detiene).
#
# Una variable que se declara fuera de la definición de una función es una variable global, y su valor es accesible y modificable en todo el programa. Discutiremos más sobre las variables globales al final de la práctica de laboratorio.

# %%
# Function Definition

def square(a):
    
    # Local variable b
    b = 1
    c = a * a + b
    print(a, "if you square + 1", c) 
    return(c)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define la función <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">square(a)</code>, que usa <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">b</code> como variable local (solo existe dentro de la función), calcula <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">c = a * a + b</code> y lo devuelve. El parámetro <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a</code> recibe el valor con el que se llame a la función.</p>
# </div>

# %% [markdown]
# Las etiquetas se muestran en la figura:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%203/Images/FuncsVar.png" width="500" />

# %% [markdown]
# Podemos llamar a la función con una entrada de <b> 3 </b>:

# %%
# Initializes Global variable  

x = 3
# Makes function call and return function a y
y = square(x)
y

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se crea la variable global <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">x = 3</code> y se llama <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">y = square(x)</code>. El valor de <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">x</code> se pasa como argumento al parámetro <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a</code> de la función, y el resultado que ella devuelve se guarda en <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">y</code>.</p>
# </div>

# %% [markdown]
# Podemos llamar a la función con una entrada de <b> 2 </b> de una manera diferente:

# %%
# Directly enter a number as parameter

square(2)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">square(2)</code> llama a la función pasando el número 2 directamente, sin necesidad de guardarlo primero en una variable.</p>
# </div>

# %% [markdown]
# Si no hay una instrucción <code> return </code>, la función devuelve <code> None </code>. Las siguientes dos funciones son equivalentes:

# %%
# Define functions, one with return value None and other without return value

def MJ():
    print('Michael Jackson')
    
def MJ1():
    print('Michael Jackson')
    return(None)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se definen dos funciones equivalentes: <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">MJ()</code>, que solo imprime un texto sin usar <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">return</code>, y <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">MJ1()</code>, que imprime lo mismo pero además incluye <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">return(None)</code> de forma explícita. Ambas se comportan igual porque, si no hay <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">return</code>, Python devuelve <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">None</code> por defecto.</p>
# </div>

# %%
# See the output

MJ()
# Out:
# Michael Jackson

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">MJ()</code> ejecuta la función, que solo imprime "Michael Jackson" en pantalla; como no se guarda el resultado en ninguna variable ni se imprime el valor de retorno, no se ve <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">None</code>.</p>
# </div>

# %%
# See the output

MJ1()
# Out:
# Michael Jackson

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">De igual forma, <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">MJ1()</code> imprime "Michael Jackson"; el valor <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">None</code> que devuelve tampoco se muestra porque no se está imprimiendo el resultado de la llamada.</p>
# </div>

# %% [markdown]
# La impresión de la función después de una llamada revela ** None ** es la declaración de retorno predeterminada:

# %%
# See what functions returns are

print(MJ())
print(MJ1())
# Out:
# Michael Jackson
# None
# Michael Jackson
# None

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Al envolver las llamadas en <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">print()</code> (<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">print(MJ())</code> y <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">print(MJ1())</code>), ahora sí se imprime el valor que cada función <b>devuelve</b>, además del texto que imprimen internamente. Por eso aparece "Michael Jackson" seguido de "None" en ambos casos: el texto lo imprime la función, y <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">None</code> es su valor de retorno por defecto.</p>
# </div>

# %% [markdown]
# Cree una función <code> con </code> que concatene dos cadenas usando la operación de suma:

# %%
# Define the function for combining strings

def con(a, b):
    return(a + b)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define la función <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">con(a, b)</code>, que devuelve la suma (<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a + b</code>) de sus dos argumentos. Cuando <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a</code> y <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">b</code> son cadenas, el operador <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">+</code> las concatena en lugar de sumarlas numéricamente.</p>
# </div>

# %%
# Test on the con() function

con("This ", "is")
# Out:
# 'This is'

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">con(&quot;This &quot;, &quot;is&quot;)</code> concatena las dos cadenas, devolviendo "This is".</p>
# </div>

# %% [markdown]
# <h3 id="simple">Las funciones hacen las cosas más fáciles</h3>

# %% [markdown]
# Considere las dos líneas de código en <b> Block 1 </b> y <b> Block 2 </b>: el procedimiento para cada bloque es idéntico. Lo único que es diferente son los nombres y valores de las variables.

# %% [markdown]
# <h4>Block 1:</h4>

# %%
# a and b calculation block1

a1 = 4
b1 = 5
c1 = a1 + b1 + 2 * a1 * b1 - 1
if(c1 < 0):
    c1 = 0 
else:
    c1 = 5
c1

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se calcula <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">c1</code> a partir de <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a1 = 4</code> y <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">b1 = 5</code> usando una fórmula, y luego se aplica un <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">if</code>/<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">else</code> que fija <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">c1</code> en 0 si el resultado es negativo, o en 5 en caso contrario. Como el resultado de la fórmula es positivo, <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">c1</code> queda en 5.</p>
# </div>

# %% [markdown]
# <h4>Block 2:</h4>

# %%
# a and b calculation block2

a2 = 0
b2 = 0
c2 = a2 + b2 + 2 * a2 * b2 - 1
if(c2 < 0):
    c2 = 0 
else:
    c2 = 5
c2

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se repite exactamente el mismo procedimiento del bloque anterior, pero con <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a2 = 0</code> y <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">b2 = 0</code>. El resultado de la fórmula es -1 (negativo), por lo que <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">c2</code> queda en 0 según la condición <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">if</code>.</p>
# </div>

# %% [markdown]
# Podemos reemplazar las líneas de código con una función. Una función combina muchas instrucciones en una sola línea de código. Una vez que se define una función, se puede utilizar repetidamente. Puede invocar la misma función muchas veces en su programa. Puede guardar su función y usarla en otro programa o usar la función de otra persona. Las líneas de código en el código <b> Block 1 </b> y el código <b> Block 2 </b> se pueden reemplazar por la siguiente función:

# %%
# Make a Function for the calculation above

def Equation(a,b):
    c = a + b + 2 * a * b - 1
    if(c < 0):
        c = 0 
    else:
        c = 5
    return(c)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define la función <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">Equation(a, b)</code>, que empaqueta en una sola pieza de código reutilizable la misma fórmula y condición usadas en los "Block 1" y "Block 2" anteriores, evitando repetir el mismo cálculo manualmente cada vez.</p>
# </div>

# %% [markdown]
# Esta función toma dos entradas, ayb, luego aplica varias operaciones para devolver c.
# Simplemente definimos la función, reemplazamos las instrucciones con la función e ingresamos los nuevos valores de <code> a1 </code>, <code> b1 </code> y <code> a2 </code>, <code> b2 </code> como entradas. Todo el proceso se demuestra en la figura:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%203/Images/FuncsPros.gif" width="850" />

# %% [markdown]
# El código ** Block 1 ** y ** Block 2 ** ahora se pueden reemplazar con el código ** Block 3 ** y el código ** Block 4 **.

# %% [markdown]
# <h4>Block 3:</h4>

# %%
a1 = 4
b1 = 5
c1 = Equation(a1, b1)
c1

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">El código del "Block 1" se reemplaza llamando a <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">Equation(a1, b1)</code> con los mismos valores (<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a1 = 4</code>, <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">b1 = 5</code>), obteniendo el mismo resultado (5) que antes, pero con una sola línea de cálculo.</p>
# </div>

# %% [markdown]
# <h4>Block 4:</h4>

# %%
a2 = 0
b2 = 0
c2 = Equation(a2, b2)
c2

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">De la misma forma, el "Block 2" se reemplaza llamando a <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">Equation(a2, b2)</code> con <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">a2 = 0</code> y <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">b2 = 0</code>, obteniendo el mismo resultado (0) que el bloque de código original.</p>
# </div>

# %% [markdown]
# <h2 id="pre">Funciones predefinidas</h2>

# %% [markdown]
# Hay muchas funciones predefinidas en Python, así que comencemos con las más simples.

# %% [markdown]
# La función <code> print () </code>:

# %%
# Build-in function print()

album_ratings = [10.0, 8.5, 9.5, 7.0, 7.0, 9.5, 9.0, 9.5] 
print(album_ratings)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">print(album_ratings)</code> muestra en pantalla el contenido completo de la lista <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">album_ratings</code>, una función predefinida de Python que no necesita ser creada por el usuario.</p>
# </div>

# %% [markdown]
# La función <code> sum () </code> agrega todos los elementos en una lista o tupla:

# %%
# Use sum() to add every element in a list or tuple together

sum(album_ratings)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">sum(album_ratings)</code> usa la función predefinida <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">sum()</code> para sumar todos los elementos numéricos de la lista.</p>
# </div>

# %% [markdown]
# La función <code> len () </code> devuelve la longitud de una lista o tupla:

# %%
# Show the length of the list or tuple

len(album_ratings)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">len(album_ratings)</code> devuelve la cantidad de elementos que contiene la lista <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">album_ratings</code>.</p>
# </div>

# %% [markdown]
# <h2 id="if">Utilizando <code>if</code>/<code>else</code> y ciclos en Funciones</h2>

# %% [markdown]
# La función <code> return () </code> es particularmente útil si tiene alguna declaración IF en la función, cuando desea que su salida dependa de alguna condición:

# %%
# Function example

def type_of_album(artist, album, year_released):
    
    print(artist, album, year_released)
    if year_released > 1980:
        return "Modern"
    else:
        return "Oldie"
    
x = type_of_album("Michael Jackson", "Thriller", 1980)
print(x)
# Out:
# Michael Jackson Thriller 1980
# Oldie

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">type_of_album(artist, album, year_released)</code>, una función con tres parámetros que imprime los datos recibidos y usa un <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">if</code>/<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">else</code> dentro de <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">return</code> para decidir qué texto devolver según el año. Al llamarla con 1980, devuelve "Oldie" porque 1980 no es mayor a 1980.</p>
# </div>

# %% [markdown]
# Podemos usar un bucle en una función. Por ejemplo, podemos <code> imprimir </code> cada elemento en una lista:

# %%
# Print the list using for loop

def PrintList(the_list):
    for element in the_list:
        print(element)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">PrintList(the_list)</code>, una función que usa un bucle <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">for</code> en su interior para recorrer e imprimir cada elemento de cualquier lista que se le pase como argumento.</p>
# </div>

# %%
# Implement the printlist function

PrintList(['1', 1, 'the man', "abc"])
# Out:
# 1
# 1
# the man
# abc

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">PrintList([&#x27;1&#x27;, 1, &#x27;the man&#x27;, &quot;abc&quot;])</code> llama a la función con una lista que mezcla distintos tipos de datos, imprimiendo cada elemento en una línea separada, sin importar si es texto o número.</p>
# </div>

# %% [markdown]
# <h2 id="default">Establecer valores de argumento predeterminados en sus funciones personalizadas</h2>

# %% [markdown]
# Puede establecer un valor predeterminado para los argumentos en su función. Por ejemplo, en la función <code> isGoodRating () </code>, ¿qué pasaría si quisiéramos crear un umbral para lo que consideramos una buena calificación? Quizás de forma predeterminada, deberíamos tener una calificación predeterminada de 4:

# %%
# Example for setting param with default value

def isGoodRating(rating=4): 
    if(rating < 7):
        print("this album sucks it's rating is",rating)
        
    else:
        print("this album is good its rating is",rating)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">isGoodRating(rating=4)</code>, donde el parámetro <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">rating</code> tiene un <b>valor predeterminado</b> de 4. Esto significa que si la función se llama sin argumentos, usará automáticamente ese valor.</p>
# </div>

# %%
# Test the value with default value and with input

isGoodRating()
isGoodRating(10)
# Out:
# this album sucks it's rating is 4
# this album is good its rating is 10

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">isGoodRating()</code> se llama sin argumentos, por lo que usa el valor predeterminado (4) y muestra que la calificación es mala. <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">isGoodRating(10)</code> pasa un valor explícito que sobrescribe el predeterminado, mostrando que la calificación es buena.</p>
# </div>

# %% [markdown]
# <h2 id="global">Variable globales</h2>

# %% [markdown]
# Hasta ahora, hemos estado creando variables dentro de funciones, pero no hemos discutido variables fuera de la función. Se denominan variables globales.
# <br>
# Intentemos ver qué devuelve <code> printer1 </code>:

# %%
# Example of global variable

artist = "Michael Jackson"
def printer1(artist):
    internal_var = artist
    print(artist, "is an artist")
    
printer1(artist)
# Out:
# Michael Jackson is an artist

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se crea la variable global <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">artist</code> y se define <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">printer1(artist)</code>, que recibe ese valor como parámetro y crea la variable local <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">internal_var</code> dentro de la función. Al llamar a <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">printer1(artist)</code>, se imprime el mensaje esperado.</p>
# </div>

# %% [markdown]
# Si imprimimos <code> internal_var </code> obtenemos un error.

# %% [markdown]
# <b> Tenemos un error de nombre: <code> nombre 'internal_var' no está definido </code>. ¿Por qué? </b>
#
# Es porque todas las variables que creamos en la función es una <b> variable local </b>, lo que significa que la asignación de la variable no persiste fuera de la función.
#
# Pero hay una forma de crear <b> variables globales </b> desde dentro de una función de la siguiente manera:

# %%
artist = "Michael Jackson"

def printer(artist):
    global internal_var 
    internal_var= "Whitney Houston"
    print(artist,"is an artist")

printer(artist) 
printer(internal_var)
# Out:
# Michael Jackson is an artist
# Whitney Houston is an artist

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Dentro de <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">printer(artist)</code>, la palabra clave <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">global</code> le indica a Python que <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">internal_var</code> no es una variable local, sino que debe crearse (o modificarse) en el ámbito global. Por eso, después de llamar <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">printer(artist)</code>, la variable <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">internal_var</code> sigue existiendo fuera de la función y puede usarse en <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">printer(internal_var)</code>.</p>
# </div>

# %% [markdown]
# <h2 id="scope">Ámbito de una variable</h2>

# %% [markdown]
# El alcance de una variable es la parte de ese programa donde esa variable es accesible. Las variables que se declaran fuera de todas las definiciones de funciones, como la variable <code> myFavouriteBand </code> en el código que se muestra aquí, son accesibles desde cualquier lugar dentro del programa. Como resultado, se dice que tales variables tienen alcance global y se conocen como variables globales.
#      <code> myFavouriteBand </code> es una variable global, por lo que es accesible desde la función <code> getBandRating </code>, y podemos usarla para determinar la clasificación de una banda. También podemos usarlo fuera de la función, como cuando lo pasamos a la función de impresión para mostrarlo:

# %%
# Example of global variable

myFavouriteBand = "AC/DC"

def getBandRating(bandname):
    if bandname == myFavouriteBand:
        return 10.0
    else:
        return 0.0

print("AC/DC's rating is:", getBandRating("AC/DC"))
print("Deep Purple's rating is:",getBandRating("Deep Purple"))
print("My favourite band is:", myFavouriteBand)
# Out:
# AC/DC's rating is: 10.0
# Deep Purple's rating is: 0.0
# My favourite band is: AC/DC

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">La variable <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">myFavouriteBand</code> se define fuera de cualquier función, por lo que es <b>global</b>: es accesible tanto dentro de <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">getBandRating()</code> como en las líneas de <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">print()</code> fuera de la función.</p>
# </div>

# %% [markdown]
# Eche un vistazo a esta versión modificada de nuestro código. Ahora la variable <code> myFavouriteBand </code> está definida dentro de la función <code> getBandRating </code>. Una variable que se define dentro de una función se dice que es una variable local de esa función. Eso significa que solo es accesible desde dentro de la función en la que está definido. Nuestra función <code> getBandRating </code> seguirá funcionando, porque <code> myFavouriteBand </code> todavía está definida dentro de la función. Sin embargo, ya no podemos imprimir <code> myFavouriteBand </code> fuera de nuestra función, porque es una variable local de nuestra función <code> getBandRating </code>; solo se define dentro de la función <code> getBandRating </code>:

# %%
# Example of local variable

def getBandRating(bandname):
    myFavouriteBand = "AC/DC"
    if bandname == myFavouriteBand:
        return 10.0
    else:
        return 0.0

print("AC/DC's rating is: ", getBandRating("AC/DC"))
print("Deep Purple's rating is: ", getBandRating("Deep Purple"))
print("My favourite band is", myFavouriteBand)
# Out:
# AC/DC's rating is:  10.0
# Deep Purple's rating is:  0.0
# My favourite band is AC/DC

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">En esta versión, <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">myFavouriteBand</code> se define <b>dentro</b> de <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">getBandRating()</code>, por lo que es una variable <b>local</b>: la función sigue funcionando igual internamente, pero intentar usar <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">myFavouriteBand</code> fuera de la función produciría un error, ya que no existe en el ámbito global.</p>
# </div>

# %% [markdown]
# Finalmente, eche un vistazo a este ejemplo. Ahora tenemos dos definiciones de variable <code> myFavouriteBand </code>. El primero de ellos tiene un alcance global y el segundo es una variable local dentro de la función <code> getBandRating </code>. Dentro de la función <code> getBandRating </code>, la variable local tiene prioridad. ** Deep Purple ** recibirá una calificación de 10.0 cuando se pase a la función <code> getBandRating </code>. Sin embargo, fuera de la función <code> getBandRating </code>, la variable local <code> getBandRating </code> no está definida, por lo que la variable <code> myFavouriteBand </code> que imprimimos es la variable global, que tiene un valor de ** AC / DC **:

# %%
# Example of global variable and local variable with the same name

myFavouriteBand = "AC/DC"

def getBandRating(bandname):
    myFavouriteBand = "Deep Purple"
    if bandname == myFavouriteBand:
        return 10.0
    else:
        return 0.0

print("AC/DC's rating is:",getBandRating("AC/DC"))
print("Deep Purple's rating is: ",getBandRating("Deep Purple"))
print("My favourite band is:",myFavouriteBand)
# Out:
# AC/DC's rating is: 0.0
# Deep Purple's rating is:  10.0
# My favourite band is: AC/DC

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Aquí existen dos variables con el mismo nombre: una global (<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">myFavouriteBand = &quot;AC/DC&quot;</code>) y otra local dentro de <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">getBandRating()</code> (<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">myFavouriteBand = &quot;Deep Purple&quot;</code>). Dentro de la función, la variable local tiene prioridad, por eso "Deep Purple" obtiene la calificación de 10.0. Fuera de la función, en cambio, se usa la variable global, que sigue valiendo "AC/DC".</p>
# </div>

# %% [markdown]
# ### Ejemplo adicional uniendo toda la teoría:
# Funciones aplicadas a un catálogo de películas

# %%
# Función simple con retorno
def clasificar_pelicula(calificacion):
    if calificacion >= 9:
        return "Obra maestra"
    elif calificacion >= 7:
        return "Muy buena"
    else:
        return "Regular"

clasificar_pelicula(8.7)

# Función con múltiples parámetros
# Función con múltiples parámetros
def promedio_duracion(duraciones):
    total = 0
    for d in duraciones:
        total += d
    return total / len(duraciones)

promedio_duracion([175, 152, 195, 88, 136])

promedio_duracion([175, 152, 195, 88, 136])

# Función que usa una variable global vs local
presupuesto_total = 0

def agregar_presupuesto(monto):
    global presupuesto_total
    presupuesto_total += monto
    return presupuesto_total

agregar_presupuesto(50)
agregar_presupuesto(30)
print(presupuesto_total)
# Out:
# 80

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Este bloque reúne, en un solo ejemplo, todas las operaciones vistas en el cuaderno aplicadas a un catálogo de películas:</p><p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><b>Función con return e if/elif/else</b> (<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">clasificar_pelicula()</code>) para categorizar una calificación.</p><p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><b>Función con bucle interno</b> (<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">promedio_duracion()</code>) que recorre una lista para calcular un promedio.</p><p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><b>Variable global</b> (<code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">presupuesto_total</code>) modificada desde dentro de una función usando <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">global</code>, acumulando el valor entre llamadas sucesivas a <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">agregar_presupuesto()</code>.</p>
# </div>

# %% [markdown]
# <h2>Cuestionario sobre funciones</h2>

# %% [markdown]
# Cree una función que divida la primera entrada por la segunda entrada:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
def div(a, b):
    return(a/b)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se define la función <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">div(a, b)</code>, que devuelve el resultado de dividir el primer argumento entre el segundo usando el operador <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">/</code>.</p>
# </div>

# %% [markdown]
# Haz doble click __aquí__ para ver la solución..
#
# <!--
# def div(a, b):
#     return(a/b)
# -->

# %% [markdown]
# Utilice la función <code> con </code> para la siguiente pregunta.

# %%
# Usa la función con para la siguiente pregunta

def con(a, b):
    return(a + b)

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;">Se vuelve a definir la función <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">con(a, b)</code> (igual que antes), que se usará en las siguientes preguntas del cuestionario.</p>
# </div>

# %% [markdown]
# ¿Se puede usar la función <code> con </code> que definimos antes para agregar números enteros o cadenas?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
con(2, 2)
# Out:
# 4

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">con(2, 2)</code> muestra que la función también funciona con números enteros: el operador <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">+</code> los suma normalmente, devolviendo 4.</p>
# </div>

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!--
# yes, for example:
# con(2, 2)
#  -->

# %% [markdown]
# ¿Se puede usar la función <code> con </code> que definimos antes para concentrar una lista o tupla?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
con(['a', 1], ['b', 1])
# Out:
# ['a', 1, 'b', 1]

# %% [markdown]
# <div style="background:#f7f7f8; border-left:4px solid #7a7a7a; border-radius:4px; padding:12px 18px; font-family:Arial,sans-serif;">
# <p style="margin:0 0 8px 0; font-size:13.5px; font-weight:700; color:#2c2c2c;">Explicación del bloque</p>
# <p style="margin:6px 0; font-size:14px; line-height:1.55; color:#2c2c2c;"><code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">con([&#x27;a&#x27;, 1], [&#x27;b&#x27;, 1])</code> muestra que la función también funciona con listas: el operador <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">+</code> las concatena, devolviendo <code style="background:#eef0f2; color:#333; padding:1px 6px; border-radius:4px; font-size:13px;">[&#x27;a&#x27;, 1, &#x27;b&#x27;, 1]</code> en vez de sumarlas numéricamente.</p>
# </div>

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!--
# yes,for example:
# con(['a', 1], ['b', 1])
# -->

# %% [markdown]
# ## Conclusiones
#
# Las funciones evitan tener que repetir el mismo bloque de código varias veces, lo que hace los programas más cortos y fáciles de mantener. También resulta importante diferenciar entre variables locales y globales, ya que una variable creada dentro de una función no está disponible fuera de ella a menos que se retorne explícitamente. Finalmente, el uso de `return` permite que el resultado de una función se pueda guardar en una variable o utilizar en otras partes del programa, en lugar de únicamente imprimirlo.
